# %% [markdown]
# # Dataset Exploration

# %% [markdown]
# ### Set up

# %%
#imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import pearsonr, spearmanr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", palette="muted", font_scale=1.2)
plt.rcParams['figure.figsize'] = (10,5)

# %%
df = pd.read_csv('..//..//data//customer_churn_synthetic.csv')

# %% [markdown]
# ### Validation

# %%
print("=== Data Overview ===")
display(df.head())
print("\n=== Info ===")
df.info()
print("\n=== Basic Stats (Numeric Features) ===")
display(df.describe().T[['count','mean','std','min','25%','50%','75%','max']])

print("\n=== Missing Values ===")
missing = df.isna().sum()
display(missing[missing > 0])
# Out:
# === Data Overview ===
#                         customer_id  age  gender  city_population  \
# 0  0ddef00236bc4dbe8dafb2f2205f2de0   54    male           260772
# 1  3d7b776d28d74a8ca5d62b2d709759cb   45  female           224491
# 2  6e51420695d34641b42b04e2d5e9db2b   18  female              500
# 3  7fceb33efeae4008a62860b11060e7a5   40  female           147961
# 4  2ed3aef13bd84e8a80497eaaef6d2003   27  female           197537
#
#    household_size      education_level  annual_income employment_status  \
# 0               2             bachelor          40451          employed
# 1               1  secondary_education          29517             other
# 2               1               master          60995           student
# 3               3  secondary_education          23086        unemployed
# 4               4             bachelor          67014          employed
#
#    tenure_months main_account_type  ...  days_from_last_web_login  \
# ...

# %% [markdown]
# ### Target Distribution

# %%
churn_rate = df['churn'].mean()
print(f"Overall churn rate: {churn_rate:.2%}")

plt.figure()
sns.countplot(data=df, x='churn',  hue='churn', palette=['#1f77b4','#ff7f0e'])
plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()
# Out:
# Overall churn rate: 15.19%

# %% [markdown]
# ### Numeric Features Exploration

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Compact histogram grid
fig, axes = plt.subplots(len(numeric_cols)//2 + 1, 2, figsize=(14, len(numeric_cols)*2.5))
axes = axes.flatten()
for i, col in enumerate(numeric_cols):
    sns.histplot(df[col], kde=True, ax=axes[i], color='steelblue', bins=30)
    axes[i].set_title(f'{col} Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical Features Exploration

# %%
categorical_cols = df.select_dtypes(exclude=[np.number, bool]).columns.tolist()
categorical_cols.remove("customer_id")

for col in categorical_cols:
    ct = pd.crosstab(df[col], df['churn'], normalize='index')
    ct.plot(kind='bar', stacked=True, figsize=(8,4), color=['#1f77b4','#ff7f0e'])
    plt.title(f'{col} — Churn Rate by Category')
    plt.ylabel("Proportion")
    plt.legend(title="Churn", loc='upper right')
    plt.show()

# %% [markdown]
# ### Churn vs Numeric Features

# %%
target_col = "churn"

# Separate numeric and categorical features
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(exclude=[np.number, bool]).columns.tolist()
categorical_cols.remove("customer_id")

# Numeric correlations with churn
corr_with_target = df[numeric_cols + [target_col]].corr()[target_col].drop(target_col)
top_pos_corr = corr_with_target.sort_values(ascending=False).head(5)
top_neg_corr = corr_with_target.sort_values().head(5)

print("Top Positive Numeric Correlations with Churn:\n", top_pos_corr)
print("\nTop Negative Numeric Correlations with Churn:\n", top_neg_corr)

# Numeric features visualization
top_features = top_pos_corr.index.tolist() + top_neg_corr.index.tolist()
n_rows = (len(top_features) + 1) // 2
fig, axes = plt.subplots(n_rows, 2, figsize=(14, n_rows*3))
axes = axes.flatten()

for i, col in enumerate(top_features):
    sns.boxplot(
        data=df, 
        x=target_col, 
        y=col, 
        ax=axes[i], 
        color='#1f77b4'  # single color instead of palette
    )
    axes[i].set_title(f'{col} vs {target_col}', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# Categorical features visualization
cat_corr = {}
for col in categorical_cols:
    prop = df.groupby(col)[target_col].mean()
    if prop.max() - prop.min() > 0:  # only keep features that vary
        cat_corr[col] = prop.max() - prop.min()

# Top 5 categorical features with strongest churn difference
top_cat_features = sorted(cat_corr, key=cat_corr.get, reverse=True)[:5]

for col in top_cat_features:
    prop_df = df.groupby(col)[target_col].mean().sort_values(ascending=False)
    plt.figure(figsize=(8,4))
    sns.barplot(
        x=prop_df.values, 
        y=prop_df.index, 
        color='#ff7f0e'  
    )
    plt.xlabel('Churn Rate')
    plt.ylabel(col)
    plt.title(f'Churn Rate by {col}')
    plt.tight_layout()
    plt.show()
# Out:
# Top Positive Numeric Correlations with Churn:
#  complaints_12m                          0.056882
# last_support_contact_days               0.030330
# loan_payments_3m                        0.028430
# support_contacts_12m                    0.025279
# avg_time_spent_per_login_minutes_12m    0.021001
# Name: churn, dtype: float64
#
# Top Negative Numeric Correlations with Churn:
#  mobile_app_logins_3m    -0.133044
# transaction_count_3m    -0.055062
# support_contacts_3m     -0.046639
# avg_monthly_spend_12m   -0.042954
# transaction_volume_3m   -0.036721
# Name: churn, dtype: float64

# %% [markdown]
# ### Correlation Analysis

# %%
corr = df[numeric_cols].corr()
top_corr_features = corr.abs().mean().sort_values(ascending=False).head(20).index.tolist()

plt.figure(figsize=(18,14))
sns.heatmap(df[top_corr_features].corr(), annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title("Correlation Heatmap (Top 20 Numeric Features)")
plt.show()

# Print top positive/negative correlations
corr_pairs = (
    corr.stack()
    .reset_index()
    .rename(columns={'level_0':'Feature1','level_1':'Feature2',0:'Correlation'})
)
corr_pairs = corr_pairs[corr_pairs['Feature1'] != corr_pairs['Feature2']]
corr_pairs['AbsCorr'] = corr_pairs['Correlation'].abs()
top_pos = corr_pairs.sort_values('Correlation', ascending=False).head(10)
top_neg = corr_pairs.sort_values('Correlation', ascending=True).head(10)
print("Top Positive Correlations:\n", top_pos[['Feature1','Feature2','Correlation']])
print("\nTop Negative Correlations:\n", top_neg[['Feature1','Feature2','Correlation']])
# Out:
# Top Positive Correlations:
#                       Feature1                 Feature2  Correlation
# 156             annual_income     avg_monthly_spend_3m     0.797585
# 831      avg_monthly_spend_3m            annual_income     0.797585
# 1032    transaction_volume_3m     transaction_count_3m     0.715563
# 942      transaction_count_3m    transaction_volume_3m     0.715563
# 239     num_standard_accounts          num_of_accounts     0.682135
# 419           num_of_accounts    num_standard_accounts     0.682135
# 798   avg_monthly_balance_12m   avg_monthly_balance_3m     0.668946
# 753    avg_monthly_balance_3m  avg_monthly_balance_12m     0.668946
# 157             annual_income    avg_monthly_spend_12m     0.608895
# 877     avg_monthly_spend_12m            annual_income     0.608895
#
# Top Negative Correlations:
#                         Feature1                   Feature2  Correlation
# 1368        support_contacts_3m  last_support_contact_days    -0.427311
# ...
