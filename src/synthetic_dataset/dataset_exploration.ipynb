# %% [markdown]
# # Dataset Exploration

# %%
#imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import pearsonr, spearmanr

# %%
df = pd.read_csv('generate/llm_generated_customers.csv')
df
# Out:
#                            customer_id  age  gender  city_population  \
# 0     8613df8261234a8ead3867dce629cf1a   47  female          1078885
# 1     ffed96424dea4671aaef0f0a96412627   35  female          1727578
# 2     b40cc89b073146249825fa849cf9ca1e   68    male          2648164
# 3     85248edc44dc4956acd3217c17dff295   18    male          1847075
# 4     259254a46ceb4c50a97238a5e1cd85d8   96  female          1204885
# ...                                ...  ...     ...              ...
# 9995  bef8c57eec4e488293304f8eb68469f1   19    male            88782
# 9996  61488f89460e417188edfab1fde62c57   58    male          1088968
# 9997  c302a493e816453da6c43cdcfdda9b46   49  female          1361817
# 9998  ae830ebdf5f44614acd270ee92aa55bb   83  female           873751
# 9999  30920e72dfbd4bbd80ca652741e3caf2   20    male           482965
#
#       household_size  annual_income      education_level employment_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 58 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   customer_id                           10000 non-null  object
#  1   age                                   10000 non-null  int64
#  2   gender                                10000 non-null  object
#  3   city_population                       10000 non-null  int64
#  4   household_size                        10000 non-null  int64
#  5   annual_income                         10000 non-null  float64
#  6   education_level                       10000 non-null  object
#  7   employment_status                     10000 non-null  object
#  8   tenure_months                         10000 non-null  int64
#  9   main_account_type                     10000 non-null  object
#  10  number_of_accounts                    10000 non-null  int64
# ...

# %%
df.select_dtypes(include=[np.number]).describe().T[['count','mean','std','min','25%','50%','75%','max']]
# Out:
#                                         count          mean            std  \
# age                                   10000.0  5.914950e+01      24.151660
# city_population                       10000.0  1.496712e+06  862362.295841
# household_size                        10000.0  2.967100e+00       1.422118
# annual_income                         10000.0  3.008895e+04    9954.848444
# tenure_months                         10000.0  5.951630e+01      34.550790
# number_of_accounts                    10000.0  2.011600e+00       0.817149
# num_standard_accounts                 10000.0  9.994000e-01       0.810719
# num_savings_accounts                  10000.0  4.992000e-01       0.500024
# num_student_accounts                  10000.0  4.926000e-01       0.499970
# num_business_accounts                 10000.0  5.093000e-01       0.499939
# number_of_debit_cards                 10000.0  9.819000e-01       0.816602
# ...

# %%
# Distribution of target
df["churn"].value_counts(normalize=True)
# Out:
# churn
# False    0.8948
# True     0.1052
# Name: proportion, dtype: float64

# %%
# Get all columns except customer_id
cols_to_plot = [col for col in df.columns if col != 'customer_id']

# Iterate through each column and create a distribution chart
for col in cols_to_plot:
    # Determine if column is numeric or categorical
    if df[col].dtype in [np.number, 'int64', 'float64', 'int32', 'float32']:
        # Numeric column: histogram with KDE
        fig, ax = plt.subplots(figsize=(10, 4))
        sns.histplot(data=df, x=col, kde=True, ax=ax, color='steelblue', bins=30)
        ax.set_title(f'Distribution of {col} (Numeric)', fontsize=14, fontweight='bold')
        ax.set_ylabel('Frequency')
        plt.tight_layout()
        plt.show()
    else:
        # Categorical column: bar chart
        fig, ax = plt.subplots(figsize=(10, 4))
        value_counts = df[col].value_counts()
        # Show top 20 categories if there are many
        if len(value_counts) > 20:
            value_counts = value_counts.head(20)
        sns.barplot(x=value_counts.values, y=value_counts.index, ax=ax, palette='husl')
        ax.set_title(f'Distribution of {col} (Top Categories)', fontsize=14, fontweight='bold')
        ax.set_xlabel('Count')
        plt.tight_layout()
        plt.show()

print(f"Distribution charts completed for {len(cols_to_plot)} columns")
# Out:
# C:\Users\z.maszlanka\AppData\Local\Temp\ipykernel_45708\982969880.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.values, y=value_counts.index, ax=ax, palette='husl')
# C:\Users\z.maszlanka\AppData\Local\Temp\ipykernel_45708\982969880.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.values, y=value_counts.index, ax=ax, palette='husl')
# C:\Users\z.maszlanka\AppData\Local\Temp\ipykernel_45708\982969880.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# Correlation Analysis between numeric features

# Select only numeric columns for correlation analysis
numeric_df = df.select_dtypes(include=[np.number])

print("=" * 80)
print("CORRELATION ANALYSIS")
print("=" * 80)

# 1. Compute Pearson correlation matrix
pearson_corr = numeric_df.corr(method='pearson')
print("\nPearson Correlation Matrix (top 15x15 features):")
print(pearson_corr.iloc[:15, :15])

# 2. Spearman correlation (for robustness, especially with outliers)
spearman_corr = numeric_df.corr(method='spearman')
print("\nSpearman Correlation Matrix (top 15x15 features):")
print(spearman_corr.iloc[:15, :15])

# 3. Find strongest positive and negative correlations (excluding diagonal)
corr_pairs = []
for i in range(len(pearson_corr.columns)):
    for j in range(i+1, len(pearson_corr.columns)):
        col1 = pearson_corr.columns[i]
        col2 = pearson_corr.columns[j]
        corr_value = pearson_corr.iloc[i, j]
        corr_pairs.append({'Feature1': col1, 'Feature2': col2, 'Correlation': corr_value})

corr_df = pd.DataFrame(corr_pairs)
corr_df['Abs_Correlation'] = corr_df['Correlation'].abs()
corr_df = corr_df.sort_values('Abs_Correlation', ascending=False)

print("\n" + "=" * 80)
print("TOP 20 STRONGEST CORRELATIONS (by absolute value):")
print("=" * 80)
print(corr_df.head(20).to_string(index=False))

print("\n" + "=" * 80)
print("TOP 10 POSITIVE CORRELATIONS:")
print("=" * 80)
print(corr_df.nlargest(10, 'Correlation')[['Feature1', 'Feature2', 'Correlation']].to_string(index=False))

print("\n" + "=" * 80)
print("TOP 10 NEGATIVE CORRELATIONS:")
print("=" * 80)
print(corr_df.nsmallest(10, 'Correlation')[['Feature1', 'Feature2', 'Correlation']].to_string(index=False))

# 4. Visualize correlation heatmap
# Limit to top features to avoid overcrowding
top_features = numeric_df.mean().abs().nlargest(20).index.tolist()
corr_subset = numeric_df[top_features].corr(method='pearson')

fig, ax = plt.subplots(figsize=(14, 12))
sns.heatmap(corr_subset, annot=True, fmt='.2f', cmap='coolwarm', center=0, 
            cbar_kws={'label': 'Pearson Correlation'}, ax=ax, square=True)
ax.set_title('Correlation Heatmap (Top 20 Features by Mean Magnitude)', fontsize=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

# 5. Summary statistics
print("\n" + "=" * 80)
print("CORRELATION SUMMARY STATISTICS:")
print("=" * 80)
print(f"Total number of numeric features: {len(numeric_df.columns)}")
print(f"Total pairwise correlations: {len(corr_df)}")
print(f"Mean absolute correlation: {corr_df['Abs_Correlation'].mean():.4f}")
print(f"Median absolute correlation: {corr_df['Abs_Correlation'].median():.4f}")
print(f"Max correlation: {corr_df['Correlation'].max():.4f}")
print(f"Min correlation: {corr_df['Correlation'].min():.4f}")
print(f"Features with no missing values: {numeric_df.dropna(axis=1, how='any').shape[1]}")

print("\nCorrelation analysis completed!")
# Out:
# ...
# CORRELATION ANALYSIS
# ...
#
# Pearson Correlation Matrix (top 15x15 features):
#                              age  city_population  household_size  \
# age                     1.000000        -0.008318       -0.018440
# city_population        -0.008318         1.000000       -0.011154
# household_size         -0.018440        -0.011154        1.000000
# annual_income           0.009274         0.007463        0.015199
# tenure_months           0.000440         0.017536       -0.019029
# number_of_accounts     -0.010289        -0.010864        0.003082
# num_standard_accounts   0.013274         0.003335       -0.009125
# num_savings_accounts   -0.000905         0.014774       -0.017406
# num_student_accounts    0.015078        -0.004355        0.012668
# num_business_accounts  -0.013488        -0.018271       -0.004141
# number_of_debit_cards   0.003925         0.002174       -0.001718
# number_of_credit_cards  0.004480        -0.001815       -0.019841
# ...

# %%
churn_rate = df["churn"].mean()
print("Overall churn rate:", churn_rate)
# Out:
# Overall churn rate: 0.1052

# %%
important_num_features = [
    "tenure_months",
    "current_balance",
    "avg_monthly_balance_3m",
    "transaction_count_3m",
    "mobile_app_logins_3m",
    "days_from_last_login",
    "annual_income",
    "age"
]

for col in important_num_features:
    plt.figure(figsize=(8,4))
    sns.boxplot(data=df, x="churn", y=col)
    plt.title(f"{col} vs Churn")
    plt.show()

# %%
categorical_cols = df.select_dtypes(exclude=[np.number, bool]).columns.tolist()

for col in categorical_cols:
    ct = pd.crosstab(df[col], df["churn"], normalize="index")
    ct.plot(kind="bar", figsize=(8,4))
    plt.title(f"{col} — Churn Comparison")
    plt.ylabel("Proportion")
    plt.show()
